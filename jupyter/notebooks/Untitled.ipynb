# %%
# RAGデータ投入処理

# %%
# コレクションの削除
client.delete_collection("daily_docs")  # コレクション名を指定
client.delete_collection("weekly_docs")  # コレクション名を指定
client.delete_collection("monthly_docs")  # コレクション名を指定

# %%
# ✅ PDF のテキスト抽出・クリーニング・要約
def extract_text_from_pdf(pdf_path, use_summary=True):
    """PDFからマーケット情報を抽出し、クリーニング後にGeminiで要約"""
    reader = PdfReader(pdf_path)
    raw_text = "\n".join([page.extract_text() for page in reader.pages if page.extract_text()])
    
    # ✅ クリーニング処理
    clean_text = clean_pdf_text(raw_text)
    
    if use_summary:
        summary = summarize_with_gemini(clean_text)
        return summary if summary else clean_text  # 要約が失敗した場合はクリーニング済みテキストを返す

    return clean_text  # 要約を使わない場合はクリーンテキストのみ

def clean_pdf_text(text):
    """抽出したテキストを整形して不要な部分を削除"""

    # ✅ ページ番号やURLの削除
    text = re.sub(r"\s*[-_]+\s*\d+/\d+\s*[-_]+", "", text)  # "1/3", "2/3" などのページ表記
    text = re.sub(r"https?://\S+", "", text)  # URLを削除

    # ✅ 免責事項・注意書きを削除
    exclusion_patterns = [
        r"本資料に関してご留意頂きたい事項.*$",
        r"出所）.*?$",
        r"本資料は.*?作成されたものです。",
        r"本資料は、作成時点 で.*$",
        r"本資料の内容は.*?変更されることがあります。",
        r"本資料は.*?保証するものではありません。",
        r"本資料に示す意見等は.*?限りません。",
        r"本資料中で使用している指数について.*$",
    ]
    for pattern in exclusion_patterns:
        text = re.sub(pattern, "", text, flags=re.MULTILINE)

    # ✅ 連続する空白・改行の削除
    text = re.sub(r"\n\s*\n", "\n", text)  # 空行を削除
    text = re.sub(r"[ \t]+", " ", text)  # 連続する空白を1つに
    text = text.strip()

    return text

def summarize_with_gemini(text):
    """Gemini に問い合わせてテキストの要約を取得"""
    prompt = f"""
    以下のマーケット情報の要点を簡潔に要約してください：
    
    {text}
    
    観点：[1. 主要金融市場の動き, 2. 主要国株式の動き, 3. マーケットの動き, 4. 注目点]
    なお、免責事項などの記載は無駄な文章なので除外して。
    """
    try:
        gemini_model = genai.GenerativeModel("gemini-1.5-flash")
        response = gemini_model.generate_content(prompt)
        if hasattr(response, "text") and response.text:
            return response.text.strip().replace("\n"," ").replace("*","")
        else:
            print(f"⚠️ 要約取得失敗: {response}")
            return None
    except Exception as e:
        print(f"❌ Gemini 要約エラー: {str(e)}")
        return None

# %%
# データ投入用関数群
import os
import pdfplumber
import chromadb
import google.generativeai as genai
import uuid
from langchain.text_splitter import RecursiveCharacterTextSplitter
import re
from PyPDF2 import PdfReader

# ✅ 環境変数からAPIキーを設定
genai.configure(api_key=os.getenv("GEMINI_API_KEY"))

# ✅ ChromaDB の HTTP クライアント（Docker コンテナの chromadb に接続）
client = chromadb.HttpClient(host="chromadb", port=8000)

# ✅ コレクション作成
collections = {
    "daily": client.get_or_create_collection("daily_docs"),
    "weekly": client.get_or_create_collection("weekly_docs"),
    "monthly": client.get_or_create_collection("monthly_docs"),
}

# ✅ 適切な埋め込みモデルを利用
EMBEDDING_MODEL = "models/text-embedding-004"  # 高精度な768次元埋め込み

def get_gemini_embedding(text):
    """Gemini APIを使用してテキストの埋め込みを取得"""
    try:
        response = genai.embed_content(model=EMBEDDING_MODEL, content=text)
        if "embedding" in response:
            return response["embedding"]
        else:
            print(f"⚠️ 埋め込み取得失敗（レスポンス不正）: {response}")
            return None
    except Exception as e:
        print(f"❌ 埋め込みエラー: {str(e)}")
        return None

# ✅ チャンク化（トークンベースで分割 & オーバーラップ設定）
def split_text(text, chunk_size=300, overlap=50):
    """テキストを適切なチャンクサイズで分割"""
    text_splitter = RecursiveCharacterTextSplitter(
        chunk_size=chunk_size, chunk_overlap=overlap, length_function=len
    )
    return text_splitter.split_text(text)

# ✅ PDF のテキストを用途別に登録（チャンク分割対応 & Gemini要約適用）
def process_pdf(file_path, category):
    """PDFファイルを読み込んでGeminiで要約し、ChromaDBへ登録（チャンク分割対応）"""
    if category not in collections:
        print(f"⚠️ 未知のカテゴリ '{category}' を 'other' に変更")
        category = "other"

    # ✅ PDF からクリーニングしたテキストを取得
    summarized_text = extract_text_from_pdf(file_path, use_summary=True)
    
    if not summarized_text.strip():
        print(f"⚠️ {file_path} はテキストを抽出できませんでした")
        return
    
    # ✅ トークンベースで分割
    text_chunks = split_text(summarized_text)

    for idx, chunk in enumerate(text_chunks):
        embedding = get_gemini_embedding(chunk)
        if embedding is None:
            print(f"⚠️ 埋め込み失敗: チャンク {idx+1}/{len(text_chunks)} (ファイル: {file_path})")
            continue

        doc_id = str(uuid.uuid4())  # ユニークなIDを生成

        try:
            collections[category].add(
                ids=[doc_id],
                documents=[chunk],
                metadatas=[{"source": file_path, "category": category, "chunk_index": idx}],
                embeddings=[embedding]
            )
            print(f"✅ チャンク {idx+1}/{len(text_chunks)} 登録完了: {file_path} → {category} (ID: {doc_id})")

        except Exception as e:
            print(f"❌ ChromaDB 登録エラー: {str(e)}")

# %%
# ✅ テスト用PDFの登録
INPUT_DIR = "input/data-rag/"
pdf_files = {
    INPUT_DIR + "daily250221.pdf": "daily",
    INPUT_DIR + "daily250220.pdf": "daily",
    INPUT_DIR + "daily250219.pdf": "daily",
    INPUT_DIR + "daily250218.pdf": "daily",
    INPUT_DIR + "250217_weekly.pdf": "weekly",
    INPUT_DIR + "250210_weekly.pdf": "weekly",
    INPUT_DIR + "250203_weekly.pdf": "weekly",
    INPUT_DIR + "monthly_2502.pdf": "monthly",
}

for file, category in pdf_files.items():
    process_pdf(file, category)
# Out:
# ✅ チャンク 1/1 登録完了: input/data-rag/daily250221.pdf → daily (ID: 0e27188c-b8a7-4a95-a69e-3e4215eba9eb)
# ✅ チャンク 1/1 登録完了: input/data-rag/daily250220.pdf → daily (ID: 0b5e0c7e-fa22-4f33-bd28-0cc7e2ab2c62)
# ✅ チャンク 1/1 登録完了: input/data-rag/daily250219.pdf → daily (ID: e383c4ca-a80a-4a57-a07d-d6971f296b1d)
# ✅ チャンク 1/1 登録完了: input/data-rag/daily250218.pdf → daily (ID: af4e8b7d-1138-46a4-93b5-0657c5147933)
# ✅ チャンク 1/3 登録完了: input/data-rag/250217_weekly.pdf → weekly (ID: 9ce63654-8505-4dca-b721-e2bdc28a71d1)
# ✅ チャンク 2/3 登録完了: input/data-rag/250217_weekly.pdf → weekly (ID: 576a02c2-12a2-44e8-8f47-08ceaca57de6)
# ✅ チャンク 3/3 登録完了: input/data-rag/250217_weekly.pdf → weekly (ID: e2ddb008-d099-4f13-b8e1-72ed40ddcde9)
# ✅ チャンク 1/3 登録完了: input/data-rag/250210_weekly.pdf → weekly (ID: 255cc25f-cf1d-4d4b-92a7-fbae1128328f)
# ✅ チャンク 2/3 登録完了: input/data-rag/250210_weekly.pdf → weekly (ID: 57930c25-5393-4320-ab8f-fcae6fa9d1db)
# ✅ チャンク 3/3 登録完了: input/data-rag/250210_weekly.pdf → weekly (ID: 9f60a0d2-a83e-4991-a29a-59de7c1d6947)
# ✅ チャンク 1/2 登録完了: input/data-rag/250203_weekly.pdf → weekly (ID: 61e5fc05-f6f2-4c39-8b04-0d5f75a39318)
# ✅ チャンク 2/2 登録完了: input/data-rag/250203_weekly.pdf → weekly (ID: 3d6f381f-99f8-4f5a-bd7f-9020a9fcbe60)
# ✅ チャンク 1/2 登録完了: input/data-rag/monthly_2502.pdf → monthly (ID: bf49adfb-6d16-4532-9229-c4310e84f3fb)
# ✅ チャンク 2/2 登録完了: input/data-rag/monthly_2502.pdf → monthly (ID: 82edbb8b-9e7a-46de-b5f4-875cee479f08)

# %%
# RAGへ問い合わせ用関数群
# ✅ ChromaDB 内のデータを確認
def check_chromadb_data():
    """ChromaDB にデータが正しく登録されているか確認"""
    for category, collection in collections.items():
        try:
            data = collection.peek()
            print(f"📌 {category} コレクションのデータ:")
            print(data)
        except Exception as e:
            print(f"⚠️ コレクション {category} のデータ確認エラー: {str(e)}")

# ✅ クエリのリライト（LLMを利用）
def rewrite_query(query):
    """LLM を使ってクエリを拡張"""
    prompt = f"""
    ユーザーのクエリをより具体的に拡張してください。
    
    クエリ: {query}
    
    出力例: 2025年2月の金融市場動向と米国株式市場の関係
    """
    try:
        gemini_model = genai.GenerativeModel("gemini-1.5-flash")
        response = gemini_model.generate_content(prompt)
        if hasattr(response, "text") and response.text:
            print(f"🟢 クエリ拡張成功: {response.text}")
            return response.text.strip()
        else:
            print(f"⚠️ クエリ拡張失敗（レスポンス不正）: {response}")
            return query
    except Exception as e:
        print(f"❌ クエリ拡張エラー: {str(e)}")
        return query

# ✅ ChromaDB に問い合わせ（類似度フィルタ適用）
def retrieve_relevant_info(query: str, top_k=3, min_score=0.1):
    """ChromaDB から類似情報を取得（類似度閾値なし）"""
    expanded_query = rewrite_query(query)  # クエリ拡張
    print(f"🟢 クエリ拡張後: {expanded_query}")

    query_embedding = get_gemini_embedding(expanded_query)  # ✅ クエリをベクトル化
    if query_embedding is None:
        print("❌ クエリ埋め込みの取得に失敗しました")
        return "🔍 クエリの埋め込みに失敗しました。"

    # ✅ クエリ埋め込みの次元確認
    print(f"✅ クエリの埋め込みベクトルの次元: {len(query_embedding)}")

    # ✅ ChromaDB に格納されているデータの埋め込み次元確認
    peek_data = collections["daily"].peek()
    if "embeddings" in peek_data and len(peek_data["embeddings"]) > 0:
        print(f"✅ 格納済みデータの埋め込みベクトルの次元: {len(peek_data['embeddings'][0])}")
    
    try:
        results = collections["daily"].query(
            query_embeddings=[query_embedding],
            n_results=top_k,
            include=["documents", "metadatas", "distances"]
        )
    except Exception as e:
        print(f"❌ クエリ実行エラー: {str(e)}")
        return "🔍 クエリの実行に失敗しました。"

    if not results.get("documents"):
        return "🔍 関連情報なし"

    retrieved_docs = []
    for i in range(len(results["documents"][0])):
        score = results["distances"][0][i]
        if score < min_score:
            continue  # スコアが低すぎる場合は無視

        retrieved_docs.append(f"🔹 類似情報 {i+1}: {results['documents'][0][i][:200]}...")
        retrieved_docs.append(f"📝 メタデータ: {results['metadatas'][0][i]}")
        retrieved_docs.append(f"🔢 類似度スコア: {score:.4f}")
        retrieved_docs.append("-" * 50)

    return "\n".join(retrieved_docs) if retrieved_docs else "🔍 適切な情報が見つかりませんでした。"
    for i in range(len(results["documents"][0])):
        retrieved_docs.append(f"🔹 類似情報 {i+1}: {results['documents'][0][i][:200]}...")
        retrieved_docs.append(f"📝 メタデータ: {results['metadatas'][0][i]}")
        retrieved_docs.append(f"🔢 類似度スコア: {results['distances'][0][i]:.4f}")
        retrieved_docs.append("-" * 50)

    return "\n".join(retrieved_docs) if retrieved_docs else "🔍 適切な情報が見つかりませんでした。"

# ✅ LLM に検索結果を要約させる
def summarize_retrieved_info(query: str, top_k=3):
    """RAG 検索結果を LLM で要約"""
    retrieved_docs = retrieve_relevant_info(query, top_k)
    
    if "🔍 適切な情報が見つかりませんでした。" in retrieved_docs:
        print("❌ 要約不可: 適切な検索結果がありません。")
        return "🔍 要約できる情報が見つかりませんでした。"

    summary_prompt = f"""
    あなたは金融市場の専門家です。
    以下の情報を要約し、最近の金融市場の動向について詳しく解説してください。

    ### 🔍 検索結果:
    {retrieved_docs}

    ---
    
    要約:
    """
    try:
        gemini_model = genai.GenerativeModel("gemini-1.5-flash")
        response = gemini_model.generate_content(summary_prompt)
        
        if hasattr(response, "text") and response.text:
            print(f"📝 要約成功: {response.text.strip()}")
            return response.text.strip()
        else:
            print(f"⚠️ 要約失敗（レスポンス不正）: {response}")
            return "🔍 要約生成に失敗しました。"

    except Exception as e:
        print(f"❌ 要約エラー: {str(e)}")
        return "🔍 要約の生成に失敗しました。"

# %%
# ✅ 検証用コード
if __name__ == "__main__":
    check_chromadb_data()  # ChromaDB にデータが登録されているか確認

    # クエリの実行と LLM での要約
    query_text = "マーケットの動きとして日本動向を教えて"
    summary_info = summarize_retrieved_info(query_text, top_k=3)

    print("\n=== 🔥 LLM による要約結果 ===")
    print(summary_info)
# Out:
# 📌 daily コレクションのデータ:
# {'ids': ['0e27188c-b8a7-4a95-a69e-3e4215eba9eb', '0b5e0c7e-fa22-4f33-bd28-0cc7e2ab2c62', 'e383c4ca-a80a-4a57-a07d-d6971f296b1d', 'af4e8b7d-1138-46a4-93b5-0657c5147933'], 'embeddings': array([[ 0.00895457,  0.02992844,  0.01273694, ..., -0.04591253,
#          0.05165695, -0.0279527 ],
#        [-0.00369174,  0.02553232,  0.00575919, ..., -0.03026854,
#          0.05744867, -0.01060821],
#        [ 0.01338212,  0.02822397, -0.02249661, ..., -0.01776579,
#          0.04947588, -0.01638838],
#        [ 0.02455232,  0.03504896, -0.03395839, ..., -0.02619648,
#          0.04096452, -0.02295619]]), 'metadatas': [{'category': 'daily', 'chunk_index': 0, 'source': 'input/data-rag/daily250221.pdf'}, {'category': 'daily', 'chunk_index': 0, 'source': 'input/data-rag/daily250220.pdf'}, {'category': 'daily', 'chunk_index': 0, 'source': 'input/data-rag/daily250219.pdf'}, {'category': 'daily', 'chunk_index': 0, 'source': 'input/data-rag/daily250218.pdf'}], 'documents': ['2月20日、主要市場は概ね下落。日経平均株価は486.57円安の38,678.04円、NYダウは450.94ドル安の44,176.65ドル。S&P500も下落。ウォルマートの業績予想下方修正が消費への懸念を高めた。円高進行と日銀追加利上げ観測も日本株軟調に影響。原油価格は上昇、金価格は上昇。米ドルは対円で下落、ユーロは対米ドルで上昇。注目点は、米欧の製造業回復が一時的なものか持続的なものか。2月のPMI速報が注目される。', '2月19日、日経平均株価は105.79円下落し、39,164.61円で取引終了。トランプ政権の関税政策と日銀の追加利上げ懸念が影響。欧州株も大幅下落。一方、米国株は小幅上昇。NYダウは71.25ドル上昇。原油価格は上昇、金価格は下落。円高が進み、10年国債利回りは1.435%と約15年ぶりの高水準。ニュージーランドは政策金利を0.5%引き下げ。今後の注目点は、米FRB高官の発言と豪州の1月雇用統計。', '2月18日、主要市場は上昇基調。日経平均株価は続伸し39,270.40円、TOPIXは2,775.51と上昇。ウクライナ・ロシア戦争終結への期待感の高まりが背景。欧州株も上昇、ドイツDAXは最高値更新。米国株も小幅高。一方、豪州は政策金利を4.35%から4.10%に引き下げたものの、追加緩和には慎重な姿勢を示した。日本10年国債利回りは1.4%台に上昇。円安ドル高傾向で、米ドル/円は一時152円台をつけた。', '2月17日、日本の好調な経済成長と日銀の利上げ継続観測を受け、国内金利が上昇し円高に。日経平均株価は小幅反発も方向感に欠き、TOPIXも上昇。欧州株は防衛関連株の上昇でストックス欧州600指数が0.5%上昇、DAXは最高値更新。米国市場は祝日で休場。WTI原油とCOMEX金先物は休場。豪中銀は利下げ転換の見通し。米連邦準備理事会（FRB）は金融政策を「良い状態」と評価しつつ、慎重な姿勢を示した。'], 'data': None, 'uris': None, 'included': ['embeddings', 'documents', 'metadatas']}
# 📌 weekly コレクションのデータ:
# {'ids': ['9ce63654-8505-4dca-b721-e2bdc28a71d1', '576a02c2-12a2-44e8-8f47-08ceaca57de6', 'e2ddb008-d099-4f13-b8e1-72ed40ddcde9', '255cc25f-cf1d-4d4b-92a7-fbae1128328f', '57930c25-5393-4320-ab8f-fcae6fa9d1db', '9f60a0d2-a83e-4991-a29a-59de7c1d6947', '61e5fc05-f6f2-4c39-8b04-0d5f75a39318', '3d6f381f-99f8-4f5a-bd7f-9020a9fcbe60'], 'embeddings': array([[ 0.01934628,  0.0175941 , -0.04011978, ..., -0.05059689,
#          0.03536846,  0.01763779],
#        [ 0.04067095,  0.0255317 , -0.03277628, ..., -0.02344801,
#          0.04534351, -0.01973774],
#        [ 0.02681291,  0.0705879 , -0.03460733, ..., -0.03534675,
#          0.08601504, -0.05411684],
#        ...,
#        [-0.00361471,  0.05154934, -0.04492979, ..., -0.00239951,
#          0.05098789, -0.00627147],
#        [ 0.01916951,  0.0177709 , -0.03605753, ..., -0.08431517,
#          0.01972056, -0.0462846 ],
#        [ 0.00749685,  0.03470874, -0.06657258, ..., -0.00233436,
#          0.05479426, -0.06403112]]), 'metadatas': [{'category': 'weekly', 'chunk_index': 0, 'source': 'input/data-rag/250217_weekly.pdf'}, {'category': 'weekly', 'chunk_index': 1, 'source': 'input/data-rag/250217_weekly.pdf'}, {'category': 'weekly', 'chunk_index': 2, 'source': 'input/data-rag/250217_weekly.pdf'}, {'category': 'weekly', 'chunk_index': 0, 'source': 'input/data-rag/250210_weekly.pdf'}, {'category': 'weekly', 'chunk_index': 1, 'source': 'input/data-rag/250210_weekly.pdf'}, {'category': 'weekly', 'chunk_index': 2, 'source': 'input/data-rag/250210_weekly.pdf'}, {'category': 'weekly', 'chunk_index': 0, 'source': 'input/data-rag/250203_weekly.pdf'}, {'category': 'weekly', 'chunk_index': 1, 'source': 'input/data-rag/250203_weekly.pdf'}], 'documents': ['1. 主要金融市場の動き:   株式市場：先週は堅調。米国の利上げ懸念や地政学リスクにもかかわらず、冷静さを保った。日経平均株価は3週ぶりに反発 (+0.9%)。S&P500も上昇 (+1.47%)し、最高値に接近。  長期金利：米国の利下げ期待後退により上昇傾向。日本の長期金利は約15年ぶりの高水準。  為替：円安ドル高傾向。ユーロ、英ポンド、豪ドルなども対円で上昇。  2. 主要国株式の動き:   日本：日経平均株価上昇、TOPIX対象銘柄の10-12月期決算は予想を上回る企業が多く、好業績期待が株価を下支え。  米国：S&P500が上昇し最高値に接近、VIX指数は低下し市場の警戒感後退。', '米国：S&P500が上昇し最高値に接近、VIX指数は低下し市場の警戒感後退。  欧州：ストックス・ヨーロッパ600指数が最高値更新、堅調な企業決算や地政学リスクの緩和が好感された。  中国：上海総合指数上昇。  3. マーケットの動き:   景気：主要国は消費主導の景気回復基調だが、物価上昇や貿易摩擦、地政学リスクが懸念材料。日本の景気ウォッチャー調査は景況感悪化を示唆。インドネシアは堅調だが、今年前半は一時的に鈍化の可能性。英国は小幅なプラス成長だが、内需の弱さが懸念。ユーロ圏は投資家センチメント指数が改善。', '物価：米国の1月CPIは予想を上回り、物価再加速を連想させる。日本の企業物価は上昇。  金利：米国の利下げ期待後退、日本の長期金利上昇。   4. 注目点:   今週発表される2月の主要経済指標（製造業PMI、消費者物価指数など）。特に米国のFOMC議事録、日本の消費者物価指数、ドイツの総選挙は注目。  トランプ政権の関税政策の行方。  インフレの動向と、それに伴う金融政策。  ドイツ総選挙の結果と、今後の政権運営。', '1. 主要金融市場の動き:   米国の関税政策発表を巡り市場は不安定。メキシコ、カナダへの関税適用は1ヶ月延期されたものの、中国への追加関税は実施され、新たな関税発表も示唆されているため警戒感が高まっている。  円高が進行し、1ドル150円台に迫る状況。日米金利差縮小が背景にある。日本の長期金利は上昇。  米国10年債利回りは低下。財務省の国債増発計画発表が影響。  欧州では、英国が政策金利を0.25%pt追加利下げ。ユーロ圏は小売売上高減少、ドイツは鉱工業生産の大幅減と景気減速懸念が強まっている。  インドは個人所得税減税を発表し、財政赤字は縮小傾向。10年国債利回りは低下。   2.', 'インドは個人所得税減税を発表し、財政赤字は縮小傾向。10年国債利回りは低下。   2. 主要国株式の動き:   日本：日経平均株価は関税懸念から下落（-1.98%）。  米国：S&P500は小幅下落（-0.24%）。  欧州：ストックス・ヨーロッパ600は小幅上昇（0.60%）。ドイツDAXは小幅上昇（0.25%）。  中国：上海総合指数は上昇（1.63%）。   3. マーケットの動き:   為替：米ドル円は下落（-2.44%）、ユーロ円も下落（-2.74%）。  商品：原油は下落（-2.11%）、金は上昇（1.95%）。   4. 注目点:', '商品：原油は下落（-2.11%）、金は上昇（1.95%）。   4. 注目点:   今週発表される主要経済指標：米国の1月消費者物価指数、生産者物価指数、小売売上高、新規失業保険申請件数、パウエル議長の議会証言など。  トランプ政権の関税政策の今後の展開。  日本の円高と長期金利の動向。  ユーロ圏の景気減速リスク。  インドの減税効果と財政健全化の進捗。', '1. 主要金融市場の動き:   週初、日経平均株価は米国のメキシコ・カナダ・中国への関税発動懸念で急落。  米国FOMCは政策金利据え置き、利下げは急がない姿勢。市場は6月利下げを織り込む。  ユーロ圏は10-12月期GDPがゼロ成長、ECBは利下げ継続を示唆。  フィリピンは10-12月期GDP成長率が市場予想を下回るも、サービス部門は堅調。  2. 主要国株式の動き:   米国株（S&P500、ナスダック）は関税懸念と中国AI企業の低コストAIモデル出現によるハイテク株売却で下落。  日経平均株価は関税懸念と円高で下落後、下げ幅を縮小。欧米株に比べ上値が重い。', '日経平均株価は関税懸念と円高で下落後、下げ幅を縮小。欧米株に比べ上値が重い。  欧州株（ストックス・ヨーロッパ600、DAX）は上昇。  3. マーケットの動き:   リスク回避姿勢が強まり、米ドルと円が上昇、ユーロと英ポンドが下落。  原油価格は下落、金価格は上昇。  米国10年国債利回りは低下。  4. 注目点:   米国の関税政策の動向。  米国の1月ISM景気指数、1月雇用統計。  FRB関係者の発言。  英国、メキシコ、インドの金融政策決定会合。  日本の12月現金給与総額。  半導体関連株の動向。'], 'data': None, 'uris': None, 'included': ['embeddings', 'documents', 'metadatas']}
# 📌 monthly コレクションのデータ:
# {'ids': ['bf49adfb-6d16-4532-9229-c4310e84f3fb', '82edbb8b-9e7a-46de-b5f4-875cee479f08'], 'embeddings': array([[-0.01701457,  0.08097724, -0.01418456, ...,  0.02294691,
#          0.06817809, -0.02351023],
#        [ 0.02448803,  0.06093508, -0.02576839, ..., -0.04679615,
#          0.05786344, -0.02127231]]), 'metadatas': [{'category': 'monthly', 'chunk_index': 0, 'source': 'input/data-rag/monthly_2502.pdf'}, {'category': 'monthly', 'chunk_index': 1, 'source': 'input/data-rag/monthly_2502.pdf'}], 'documents': ['1. 主要金融市場の動き: 1月は米インフレ懸念後退による利下げ期待回復、トランプ政権への過剰警戒感の後退でリスク選好が強まり、米国以外の国で株式市場が活況を呈した。2月以降はトランプ政権の政策実現性に関する神経戦が展開されると予想される。  2. 主要国株式の動き: 1月は世界的に堅調だったが、ハイテク株はAI関連のニュースに大きく反応し変動。日本株は欧米株と比較して上値が重い展開。事業法人の買い越しや新NISAが下支えとなり底堅い展開が予想される。欧州株は史上最高値を更新も、政局不安や米国の関税政策への懸念が残る。米国株は堅調な景気を背景に底堅い展開だが、ハイテク株の割高感は残る。  3.', '3. マーケットの動き: 債券市場は、インフレリスクと鈍化の両方の影響を受け変動。日本は日銀の利上げ観測で長期金利が上昇。為替市場では米ドル高は一巡し、中国景気回復期待から周辺国通貨が底堅く推移する可能性。リート市場は、日本は割安感修正の兆候、米国は堅調な景気が下支えするものの、上値は重い。原油価格は政治イベントに大きく影響され変動。  4. 注目点: トランプ政権の政策実現性、各国の中央銀行の金融政策（特に米国の利下げ休止、ユーロ圏の利下げ継続、日本の利上げ）、中国景気の回復、AI開発競争、日米実質金利差、各国の政局不安、原油価格動向。'], 'data': None, 'uris': None, 'included': ['embeddings', 'documents', 'metadatas']}
# 🟢 クエリ拡張成功: いくつかの拡張例を提案します。クエリ「マーケットの動きとして日本動向を教えて」をより具体的に拡張するには、以下の要素を考慮する必要があります。
#
# **1. 対象となる市場を特定する:**
#
# * **株式市場:** 「2023年10月からの日本株式市場の動向と、日経平均株価、TOPIXの推移、主要セクターの株価変動について教えてください。」
# * **債券市場:** 「最近の日本の国債市場の動向、金利の変動、そして世界的な金利上昇との関連性について教えてください。」
# * **為替市場:** 「円ドルの為替レートの最近の動向、要因分析、今後の見通しについて教えてください。特に、日銀の金融政策との関係性を中心に説明してください。」
# * **不動産市場:** 「日本の不動産市場、特に東京圏のマンション価格の動向と今後の見通しについて教えてください。空室率や地価との関連性も考慮して。」
# * **商品市場:** 「日本の原油価格や金価格の動向、世界情勢との関連性、および今後の予想について教えてください。」
#
#
# **2. 時間軸を明確にする:**
#
# * 「過去1年間の日本の株式市場の動向を教えてください。」
# * 「直近1ヶ月の日本の為替市場の動向と、その要因を分析してください。」
# * 「2024年第1四半期の日本経済における主要なマーケット動向を教えてください。」
#
#
# **3. 影響要因を特定する:**
#
# * 「最近の円安傾向に対する日本の経済政策の影響について教えてください。」
# * 「世界的なインフレと日本のマーケット動向の関係について説明してください。」
# * 「中国経済の減速が日本のマーケットに与える影響について分析してください。」
#
#
# **4. 比較対象を設ける:**
#
# * 「日本の株式市場と米国株式市場の最近の動向を比較してください。」
# * 「日本の不動産市場と他の先進国(例えば、英国、カナダ)の不動産市場の動向を比較し、その違いと要因を分析してください。」
#
#
# **5. 特定のセクターに絞り込む:**
#
# * 「日本のテクノロジーセクターの株式市場における最近の動向と、今後の見通しについて教えてください。」
# * 「日本の自動車産業における最近のマーケット動向と、世界的なサプライチェーン問題との関連性について説明してください。」
#
#
# これらの要素を組み合わせることで、より具体的で詳細な情報を引き出すことができます。 例えば、「2023年下半期における日本の株式市場の動向、特にテクノロジーセクターの動向と、米国株式市場との比較、そして日銀の金融政策との関連性について教えてください。」というように。
#
# 🟢 クエリ拡張後: いくつかの拡張例を提案します。クエリ「マーケットの動きとして日本動向を教えて」をより具体的に拡張するには、以下の要素を考慮する必要があります。
#
# **1. 対象となる市場を特定する:**
#
# * **株式市場:** 「2023年10月からの日本株式市場の動向と、日経平均株価、TOPIXの推移、主要セクターの株価変動について教えてください。」
# * **債券市場:** 「最近の日本の国債市場の動向、金利の変動、そして世界的な金利上昇との関連性について教えてください。」
# * **為替市場:** 「円ドルの為替レートの最近の動向、要因分析、今後の見通しについて教えてください。特に、日銀の金融政策との関係性を中心に説明してください。」
# * **不動産市場:** 「日本の不動産市場、特に東京圏のマンション価格の動向と今後の見通しについて教えてください。空室率や地価との関連性も考慮して。」
# * **商品市場:** 「日本の原油価格や金価格の動向、世界情勢との関連性、および今後の予想について教えてください。」
#
#
# **2. 時間軸を明確にする:**
#
# * 「過去1年間の日本の株式市場の動向を教えてください。」
# * 「直近1ヶ月の日本の為替市場の動向と、その要因を分析してください。」
# * 「2024年第1四半期の日本経済における主要なマーケット動向を教えてください。」
#
#
# **3. 影響要因を特定する:**
#
# * 「最近の円安傾向に対する日本の経済政策の影響について教えてください。」
# * 「世界的なインフレと日本のマーケット動向の関係について説明してください。」
# * 「中国経済の減速が日本のマーケットに与える影響について分析してください。」
#
#
# **4. 比較対象を設ける:**
#
# * 「日本の株式市場と米国株式市場の最近の動向を比較してください。」
# * 「日本の不動産市場と他の先進国(例えば、英国、カナダ)の不動産市場の動向を比較し、その違いと要因を分析してください。」
#
#
# **5. 特定のセクターに絞り込む:**
#
# * 「日本のテクノロジーセクターの株式市場における最近の動向と、今後の見通しについて教えてください。」
# * 「日本の自動車産業における最近のマーケット動向と、世界的なサプライチェーン問題との関連性について説明してください。」
#
#
# これらの要素を組み合わせることで、より具体的で詳細な情報を引き出すことができます。 例えば、「2023年下半期における日本の株式市場の動向、特にテクノロジーセクターの動向と、米国株式市場との比較、そして日銀の金融政策との関連性について教えてください。」というように。
# ✅ クエリの埋め込みベクトルの次元: 768
# ✅ 格納済みデータの埋め込みベクトルの次元: 768
# 📝 要約成功: 2月17日～19日の金融市場は、ウクライナ情勢や日銀政策、米国の金融政策など様々な要因によって変動しました。
#
# **2月17日:** 日本の好調な経済成長と日銀の利上げ継続観測（実際には利上げは行われず）から円高傾向となり、日経平均株価は小幅反発にとどまりました。欧州株は防衛関連株の堅調さから上昇しました。米国市場は祝日で休場でした。豪州中銀は利下げ転換を示唆し、FRBは慎重な姿勢を維持しました。
#
# **2月18日:** ウクライナ・ロシア戦争終結への期待感から、主要市場は上昇基調となりました。日経平均株価とTOPIXは上昇し、欧州株も上昇、ドイツDAXは最高値を更新。米国株も小幅高でした。豪州は政策金利を0.25%引き下げましたが、追加緩和には慎重な姿勢を示しました。日本10年国債利回りは上昇し、円安ドル高傾向が続きました。
#
# **2月19日:** 日経平均株価は、トランプ政権の関税政策と日銀の追加利上げ懸念（市場の憶測）から大幅下落しました。欧州株も大幅下落しましたが、米国株は小幅上昇しました。円高が進み、10年国債利回りは約15年ぶりの高水準を記録しました。ニュージーランドは政策金利を引き下げました。
#
# **全体的な動向:** この期間、市場は不安定な動きを示しました。ウクライナ情勢の進展、各国の金融政策、市場の思惑などが複雑に絡み合い、株価や為替レート、債券利回りに影響を与えました。特に日銀政策に関する憶測は市場の大きな変動要因となりました。  今後の注目点は、米FRB高官の発言、豪州の雇用統計、そしてウクライナ情勢の進展です。これらの要因が市場の動向を大きく左右する可能性があります。  各国の金融政策のバランス、地政学リスク、そして市場の心理が今後の市場の動きを決定づける重要な要素となるでしょう。
#
# === 🔥 LLM による要約結果 ===
# 2月17日～19日の金融市場は、ウクライナ情勢や日銀政策、米国の金融政策など様々な要因によって変動しました。
#
# **2月17日:** 日本の好調な経済成長と日銀の利上げ継続観測（実際には利上げは行われず）から円高傾向となり、日経平均株価は小幅反発にとどまりました。欧州株は防衛関連株の堅調さから上昇しました。米国市場は祝日で休場でした。豪州中銀は利下げ転換を示唆し、FRBは慎重な姿勢を維持しました。
#
# **2月18日:** ウクライナ・ロシア戦争終結への期待感から、主要市場は上昇基調となりました。日経平均株価とTOPIXは上昇し、欧州株も上昇、ドイツDAXは最高値を更新。米国株も小幅高でした。豪州は政策金利を0.25%引き下げましたが、追加緩和には慎重な姿勢を示しました。日本10年国債利回りは上昇し、円安ドル高傾向が続きました。
#
# **2月19日:** 日経平均株価は、トランプ政権の関税政策と日銀の追加利上げ懸念（市場の憶測）から大幅下落しました。欧州株も大幅下落しましたが、米国株は小幅上昇しました。円高が進み、10年国債利回りは約15年ぶりの高水準を記録しました。ニュージーランドは政策金利を引き下げました。
#
# **全体的な動向:** この期間、市場は不安定な動きを示しました。ウクライナ情勢の進展、各国の金融政策、市場の思惑などが複雑に絡み合い、株価や為替レート、債券利回りに影響を与えました。特に日銀政策に関する憶測は市場の大きな変動要因となりました。  今後の注目点は、米FRB高官の発言、豪州の雇用統計、そしてウクライナ情勢の進展です。これらの要因が市場の動向を大きく左右する可能性があります。  各国の金融政策のバランス、地政学リスク、そして市場の心理が今後の市場の動きを決定づける重要な要素となるでしょう。

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# aiohappyeyeballs                         2.4.6
# aiohttp                                  3.11.13
# aiosignal                                1.3.2
# alembic                                  1.12.0
# altair                                   5.1.2
# annotated-types                          0.7.0
# anyio                                    4.0.0
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asgiref                                  3.8.1
# asttokens                                2.4.0
# async-generator                          1.10
# async-lru                                2.0.4
# attrs                                    23.1.0
# Babel                                    2.13.0
# backcall                                 0.2.0
# backoff                                  2.2.1
# backports.functools-lru-cache            1.6.5
# bcrypt                                   4.2.1
# beautifulsoup4                           4.12.2
# bleach                                   6.1.0
# blinker                                  1.9.0
# bokeh                                    3.3.0
# boltons                                  23.0.0
# Bottleneck                               1.3.7
# Brotli                                   1.1.0
# build                                    1.2.2.post1
# cached-property                          1.5.2
# cachetools                               5.5.2
# certifi                                  2023.7.22
# certipy                                  0.1.3
# cffi                                     1.16.0
# charset-normalizer                       3.3.0
# chroma-hnswlib                           0.7.6
# chromadb                                 0.6.3
# click                                    8.1.7
# cloudpickle                              3.1.0
# colorama                                 0.4.6
# coloredlogs                              15.0.1
# comm                                     0.1.4
# conda                                    23.9.0
# conda-package-handling                   2.2.0
# conda_package_streaming                  0.9.0
# contourpy                                1.1.1
# cryptography                             41.0.4
# cycler                                   0.12.1
# Cython                                   3.0.4
# cytoolz                                  0.12.2
# dask                                     2023.10.0
# databricks-cli                           0.18.0
# debugpy                                  1.8.0
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.18
# dill                                     0.3.7
# distributed                              2023.10.0
# docker                                   6.1.3
# durationpy                               0.9
# entrypoints                              0.4
# et-xmlfile                               1.1.0
# exceptiongroup                           1.1.3
# executing                                1.2.0
# fastapi                                  0.115.8
# fastjsonschema                           2.18.1
# filelock                                 3.17.0
# Flask                                    3.1.0
# flatbuffers                              25.2.10
# fonttools                                4.43.1
# fqdn                                     1.5.1
# frozenlist                               1.5.0
# fsspec                                   2023.9.2
# gitdb                                    4.0.10
# GitPython                                3.1.40
# gmpy2                                    2.1.2
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.24.1
# google-api-python-client                 2.161.0
# google-auth                              2.38.0
# google-auth-httplib2                     0.2.0
# google-generativeai                      0.8.4
# googleapis-common-protos                 1.68.0
# greenlet                                 3.0.0
# grpcio                                   1.70.0
# grpcio-status                            1.62.3
# gunicorn                                 21.2.0
# h11                                      0.14.0
# h5py                                     3.10.0
# httpcore                                 1.0.7
# httplib2                                 0.22.0
# httptools                                0.6.4
# httpx                                    0.28.1
# huggingface-hub                          0.29.1
# humanfriendly                            10.0
# idna                                     3.4
# imagecodecs                              2023.9.18
# imageio                                  2.31.5
# importlib-metadata                       6.8.0
# importlib-resources                      6.1.0
# ipykernel                                6.25.2
# ipympl                                   0.9.3
# ipython                                  8.16.1
# ipython-genutils                         0.2.0
# ipywidgets                               8.1.1
# isoduration                              20.11.0
# itsdangerous                             2.2.0
# jedi                                     0.19.1
# Jinja2                                   3.1.2
# joblib                                   1.3.2
# json5                                    0.9.14
# jsonpatch                                1.33
# jsonpointer                              2.4
# jsonschema                               4.19.1
# jsonschema-specifications                2023.7.1
# jupyter_client                           8.4.0
# jupyter_core                             5.4.0
# jupyter-events                           0.8.0
# jupyter-lsp                              2.2.0
# jupyter_server                           2.8.0
# jupyter-server-mathjax                   0.2.6
# jupyter_server_terminals                 0.4.4
# jupyter-telemetry                        0.1.0
# jupyterhub                               4.0.2
# jupyterlab                               4.0.7
# jupyterlab-git                           0.41.0
# jupyterlab-pygments                      0.2.2
# jupyterlab_server                        2.25.0
# jupyterlab-widgets                       3.0.9
# kiwisolver                               1.4.5
# kubernetes                               32.0.1
# langchain                                0.3.19
# langchain-core                           0.3.38
# langchain-text-splitters                 0.3.6
# langsmith                                0.3.10
# lazy_loader                              0.3
# libmambapy                               1.5.2
# llvmlite                                 0.40.1
# locket                                   1.0.0
# lz4                                      4.3.2
# Mako                                     1.2.4
# mamba                                    1.5.2
# Markdown                                 3.7
# markdown-it-py                           3.0.0
# MarkupSafe                               2.1.3
# matplotlib                               3.7.2
# matplotlib-inline                        0.1.6
# mdurl                                    0.1.2
# mistune                                  3.0.1
# mlflow                                   2.9.1
# mmh3                                     5.1.0
# monotonic                                1.6
# mpmath                                   1.3.0
# msgpack                                  1.0.6
# multidict                                6.1.0
# munkres                                  1.1.4
# nbclassic                                1.0.0
# nbclient                                 0.8.0
# nbconvert                                7.9.2
# nbdime                                   3.2.1
# nbformat                                 5.9.2
# nest-asyncio                             1.5.8
# networkx                                 3.2
# notebook                                 7.0.6
# notebook_shim                            0.2.3
# numba                                    0.57.1
# numexpr                                  2.8.7
# numpy                                    1.26.4
# oauthlib                                 3.2.2
# onnxruntime                              1.20.1
# openpyxl                                 3.1.2
# opentelemetry-api                        1.27.0
# opentelemetry-exporter-otlp-proto-common 1.27.0
# opentelemetry-exporter-otlp-proto-grpc   1.27.0
# opentelemetry-instrumentation            0.48b0
# opentelemetry-instrumentation-asgi       0.48b0
# opentelemetry-instrumentation-fastapi    0.48b0
# opentelemetry-proto                      1.27.0
# opentelemetry-sdk                        1.27.0
# opentelemetry-semantic-conventions       0.48b0
# opentelemetry-util-http                  0.48b0
# orjson                                   3.10.15
# overrides                                7.4.0
# packaging                                23.2
# pamela                                   1.1.0
# pandas                                   1.5.3
# pandocfilters                            1.5.0
# parso                                    0.8.3
# partd                                    1.4.1
# patsy                                    0.5.3
# pdfminer.six                             20231228
# pdfplumber                               0.11.5
# pexpect                                  4.8.0
# pickleshare                              0.7.5
# Pillow                                   10.1.0
# pip                                      23.3
# pkgutil_resolve_name                     1.3.10
# platformdirs                             3.11.0
# pluggy                                   1.3.0
# posthog                                  3.15.1
# prometheus-client                        0.17.1
# prompt-toolkit                           3.0.39
# propcache                                0.3.0
# proto-plus                               1.26.0
# protobuf                                 4.24.3
# psutil                                   5.9.5
# ptyprocess                               0.7.0
# pure-eval                                0.2.2
# py-cpuinfo                               9.0.0
# pyarrow                                  13.0.0
# pyasn1                                   0.6.1
# pyasn1_modules                           0.4.1
# pycosat                                  0.6.6
# pycparser                                2.21
# pycurl                                   7.45.1
# pydantic                                 2.10.6
# pydantic_core                            2.27.2
# Pygments                                 2.16.1
# PyJWT                                    2.8.0
# PyMySQL                                  1.1.1
# pyOpenSSL                                23.2.0
# pyparsing                                3.0.9
# PyPDF2                                   3.0.1
# pypdfium2                                4.30.1
# PyPika                                   0.48.9
# pyproject_hooks                          1.2.0
# PySocks                                  1.7.1
# python-dateutil                          2.8.2
# python-dotenv                            1.0.1
# python-json-logger                       2.0.7
# pytz                                     2023.3.post1
# PyWavelets                               1.4.1
# PyYAML                                   6.0.2
# pyzmq                                    25.1.1
# querystring-parser                       1.2.4
# referencing                              0.30.2
# regex                                    2024.11.6
# requests                                 2.31.0
# requests-oauthlib                        2.0.0
# requests-toolbelt                        1.0.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.9.4
# rpds-py                                  0.10.6
# rsa                                      4.9
# ruamel.yaml                              0.17.39
# ruamel.yaml.clib                         0.2.7
# safetensors                              0.5.2
# scikit-image                             0.22.0
# scikit-learn                             1.6.1
# scipy                                    1.14.1
# seaborn                                  0.12.2
# Send2Trash                               1.8.2
# sentence-transformers                    3.4.1
# setuptools                               68.2.2
# shellingham                              1.5.4
# six                                      1.16.0
# smmap                                    3.0.5
# sniffio                                  1.3.0
# sortedcontainers                         2.4.0
# soupsieve                                2.5
# SQLAlchemy                               2.0.22
# sqlparse                                 0.5.3
# stack-data                               0.6.2
# starlette                                0.45.3
# statsmodels                              0.14.0
# sympy                                    1.13.1
# tables                                   3.9.1
# tabulate                                 0.9.0
# tblib                                    2.0.0
# tenacity                                 9.0.0
# terminado                                0.17.1
# threadpoolctl                            3.2.0
# tifffile                                 2023.9.26
# tinycss2                                 1.2.1
# tokenizers                               0.21.0
# tomli                                    2.0.1
# toolz                                    0.12.0
# torch                                    2.6.0
# tornado                                  6.3.3
# tqdm                                     4.66.1
# traitlets                                5.11.2
# transformers                             4.49.0
# truststore                               0.8.0
# typer                                    0.15.1
# types-python-dateutil                    2.8.19.14
# typing_extensions                        4.12.2
# typing-utils                             0.1.0
# tzdata                                   2023.3
# uri-template                             1.3.0
# uritemplate                              4.1.1
# urllib3                                  2.0.7
# uvicorn                                  0.34.0
# uvloop                                   0.21.0
# watchfiles                               1.0.4
# wcwidth                                  0.2.8
# webcolors                                1.13
# webencodings                             0.5.1
# websocket-client                         1.6.4
# websockets                               15.0
# Werkzeug                                 3.1.3
# wheel                                    0.41.2
# widgetsnbextension                       4.0.9
# wrapt                                    1.17.2
# xlrd                                     2.0.1
# xyzservices                              2023.10.0
# yarl                                     1.18.3
# zict                                     3.0.0
# zipp                                     3.17.0
# zstandard                                0.23.0

# %%
# !pip list
# Out:
# Package                                  Version
# ---------------------------------------- ------------
# alembic                                  1.12.0
# altair                                   5.1.2
# annotated-types                          0.7.0
# anyio                                    4.0.0
# argon2-cffi                              23.1.0
# argon2-cffi-bindings                     21.2.0
# arrow                                    1.3.0
# asgiref                                  3.8.1
# asttokens                                2.4.0
# async-generator                          1.10
# async-lru                                2.0.4
# attrs                                    23.1.0
# Babel                                    2.13.0
# backcall                                 0.2.0
# backoff                                  2.2.1
# backports.functools-lru-cache            1.6.5
# bcrypt                                   4.2.1
# beautifulsoup4                           4.12.2
# bleach                                   6.1.0
# blinker                                  1.9.0
# bokeh                                    3.3.0
# boltons                                  23.0.0
# Bottleneck                               1.3.7
# Brotli                                   1.1.0
# build                                    1.2.2.post1
# cached-property                          1.5.2
# cachetools                               5.5.2
# certifi                                  2023.7.22
# certipy                                  0.1.3
# cffi                                     1.16.0
# charset-normalizer                       3.3.0
# chroma-hnswlib                           0.7.6
# chromadb                                 0.6.3
# click                                    8.1.7
# cloudpickle                              3.1.0
# colorama                                 0.4.6
# coloredlogs                              15.0.1
# comm                                     0.1.4
# conda                                    23.9.0
# conda-package-handling                   2.2.0
# conda_package_streaming                  0.9.0
# contourpy                                1.1.1
# cryptography                             41.0.4
# cycler                                   0.12.1
# Cython                                   3.0.4
# cytoolz                                  0.12.2
# dask                                     2023.10.0
# databricks-cli                           0.18.0
# debugpy                                  1.8.0
# decorator                                5.1.1
# defusedxml                               0.7.1
# Deprecated                               1.2.18
# dill                                     0.3.7
# distributed                              2023.10.0
# distro                                   1.9.0
# docker                                   6.1.3
# durationpy                               0.9
# entrypoints                              0.4
# et-xmlfile                               1.1.0
# exceptiongroup                           1.1.3
# executing                                1.2.0
# fastapi                                  0.115.8
# fastjsonschema                           2.18.1
# filelock                                 3.17.0
# Flask                                    3.1.0
# flatbuffers                              25.2.10
# fonttools                                4.43.1
# fqdn                                     1.5.1
# fsspec                                   2023.9.2
# gitdb                                    4.0.10
# GitPython                                3.1.40
# gmpy2                                    2.1.2
# google-ai-generativelanguage             0.6.15
# google-api-core                          2.24.1
# google-api-python-client                 2.162.0
# google-auth                              2.38.0
# google-auth-httplib2                     0.2.0
# google-generativeai                      0.8.4
# googleapis-common-protos                 1.68.0
# greenlet                                 3.0.0
# grpcio                                   1.70.0
# grpcio-status                            1.62.3
# gunicorn                                 21.2.0
# h11                                      0.14.0
# h5py                                     3.10.0
# httpcore                                 1.0.7
# httplib2                                 0.22.0
# httptools                                0.6.4
# httpx                                    0.28.1
# huggingface-hub                          0.29.1
# humanfriendly                            10.0
# idna                                     3.4
# imagecodecs                              2023.9.18
# imageio                                  2.31.5
# importlib-metadata                       6.8.0
# importlib-resources                      6.1.0
# ipykernel                                6.25.2
# ipympl                                   0.9.3
# ipython                                  8.16.1
# ipython-genutils                         0.2.0
# ipywidgets                               8.1.1
# isoduration                              20.11.0
# itsdangerous                             2.2.0
# jedi                                     0.19.1
# Jinja2                                   3.1.2
# joblib                                   1.3.2
# json5                                    0.9.14
# jsonpatch                                1.33
# jsonpointer                              2.4
# jsonschema                               4.19.1
# jsonschema-specifications                2023.7.1
# jupyter_client                           8.4.0
# jupyter_core                             5.4.0
# jupyter-events                           0.8.0
# jupyter-lsp                              2.2.0
# jupyter_server                           2.8.0
# jupyter-server-mathjax                   0.2.6
# jupyter_server_terminals                 0.4.4
# jupyter-telemetry                        0.1.0
# jupyterhub                               4.0.2
# jupyterlab                               4.0.7
# jupyterlab-git                           0.41.0
# jupyterlab-pygments                      0.2.2
# jupyterlab_server                        2.25.0
# jupyterlab-widgets                       3.0.9
# kiwisolver                               1.4.5
# kubernetes                               32.0.1
# lazy_loader                              0.3
# libmambapy                               1.5.2
# llvmlite                                 0.40.1
# locket                                   1.0.0
# lz4                                      4.3.2
# Mako                                     1.2.4
# mamba                                    1.5.2
# Markdown                                 3.7
# markdown-it-py                           3.0.0
# MarkupSafe                               2.1.3
# matplotlib                               3.7.2
# matplotlib-inline                        0.1.6
# mdurl                                    0.1.2
# mistune                                  3.0.1
# mlflow                                   2.9.1
# mmh3                                     5.1.0
# monotonic                                1.6
# mpmath                                   1.3.0
# msgpack                                  1.0.6
# munkres                                  1.1.4
# nbclassic                                1.0.0
# nbclient                                 0.8.0
# nbconvert                                7.9.2
# nbdime                                   3.2.1
# nbformat                                 5.9.2
# nest-asyncio                             1.5.8
# networkx                                 3.2
# notebook                                 7.0.6
# notebook_shim                            0.2.3
# numba                                    0.57.1
# numexpr                                  2.8.7
# numpy                                    1.24.4
# oauthlib                                 3.2.2
# onnxruntime                              1.20.1
# openpyxl                                 3.1.2
# opentelemetry-api                        1.27.0
# opentelemetry-exporter-otlp-proto-common 1.27.0
# opentelemetry-exporter-otlp-proto-grpc   1.27.0
# opentelemetry-instrumentation            0.48b0
# opentelemetry-instrumentation-asgi       0.48b0
# opentelemetry-instrumentation-fastapi    0.48b0
# opentelemetry-proto                      1.27.0
# opentelemetry-sdk                        1.27.0
# opentelemetry-semantic-conventions       0.48b0
# opentelemetry-util-http                  0.48b0
# orjson                                   3.10.15
# overrides                                7.4.0
# packaging                                23.2
# pamela                                   1.1.0
# pandas                                   1.5.3
# pandocfilters                            1.5.0
# parso                                    0.8.3
# partd                                    1.4.1
# patsy                                    0.5.3
# pexpect                                  4.8.0
# pickleshare                              0.7.5
# Pillow                                   10.1.0
# pip                                      23.3
# pkgutil_resolve_name                     1.3.10
# platformdirs                             3.11.0
# pluggy                                   1.3.0
# posthog                                  3.16.0
# prometheus-client                        0.17.1
# prompt-toolkit                           3.0.39
# proto-plus                               1.26.0
# protobuf                                 4.24.3
# psutil                                   5.9.5
# ptyprocess                               0.7.0
# pure-eval                                0.2.2
# py-cpuinfo                               9.0.0
# pyarrow                                  13.0.0
# pyasn1                                   0.6.1
# pyasn1_modules                           0.4.1
# pycosat                                  0.6.6
# pycparser                                2.21
# pycurl                                   7.45.1
# pydantic                                 2.10.6
# pydantic_core                            2.27.2
# Pygments                                 2.16.1
# PyJWT                                    2.8.0
# PyMySQL                                  1.1.1
# pyOpenSSL                                23.2.0
# pyparsing                                3.0.9
# PyPDF2                                   3.0.1
# PyPika                                   0.48.9
# pyproject_hooks                          1.2.0
# PySocks                                  1.7.1
# python-dateutil                          2.8.2
# python-dotenv                            1.0.1
# python-json-logger                       2.0.7
# pytz                                     2023.3.post1
# PyWavelets                               1.4.1
# PyYAML                                   6.0.2
# pyzmq                                    25.1.1
# querystring-parser                       1.2.4
# referencing                              0.30.2
# regex                                    2024.11.6
# requests                                 2.31.0
# requests-oauthlib                        2.0.0
# rfc3339-validator                        0.1.4
# rfc3986-validator                        0.1.1
# rich                                     13.9.4
# rpds-py                                  0.10.6
# rsa                                      4.9
# ruamel.yaml                              0.17.39
# ruamel.yaml.clib                         0.2.7
# safetensors                              0.5.3
# scikit-image                             0.22.0
# scikit-learn                             1.6.1
# scipy                                    1.14.1
# seaborn                                  0.12.2
# Send2Trash                               1.8.2
# sentence-transformers                    3.4.1
# setuptools                               68.2.2
# shellingham                              1.5.4
# six                                      1.16.0
# smmap                                    3.0.5
# sniffio                                  1.3.0
# sortedcontainers                         2.4.0
# soupsieve                                2.5
# SQLAlchemy                               2.0.22
# sqlparse                                 0.5.3
# stack-data                               0.6.2
# starlette                                0.45.3
# statsmodels                              0.14.0
# sympy                                    1.13.1
# tables                                   3.9.1
# tabulate                                 0.9.0
# tblib                                    2.0.0
# tenacity                                 9.0.0
# terminado                                0.17.1
# threadpoolctl                            3.2.0
# tifffile                                 2023.9.26
# tinycss2                                 1.2.1
# tokenizers                               0.21.0
# tomli                                    2.0.1
# toolz                                    0.12.0
# torch                                    2.6.0
# tornado                                  6.3.3
# tqdm                                     4.66.1
# traitlets                                5.11.2
# transformers                             4.49.0
# truststore                               0.8.0
# typer                                    0.15.1
# types-python-dateutil                    2.8.19.14
# typing_extensions                        4.12.2
# typing-utils                             0.1.0
# tzdata                                   2023.3
# uri-template                             1.3.0
# uritemplate                              4.1.1
# urllib3                                  2.0.7
# uvicorn                                  0.34.0
# uvloop                                   0.21.0
# watchfiles                               1.0.4
# wcwidth                                  0.2.8
# webcolors                                1.13
# webencodings                             0.5.1
# websocket-client                         1.6.4
# websockets                               15.0
# Werkzeug                                 3.1.3
# wheel                                    0.41.2
# widgetsnbextension                       4.0.9
# wrapt                                    1.17.2
# xlrd                                     2.0.1
# xyzservices                              2023.10.0
# zict                                     3.0.0
# zipp                                     3.17.0
# zstandard                                0.21.0
